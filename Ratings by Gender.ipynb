# %%
# Import pandas and sqlalchemy
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/IMDb ratings.csv"

# %%
ratings_data_df = pd.read_csv(csv_file)

# %%
ratings_data_df.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
# Removed irrelevant columns and reorganized the votes by gender regardless of age.
# The "mean_vote" and "median_vote" columns were also removed due to redundancy. 
# The "total_votes" and "weighted_average_vote" columns were switched around for the sake of clarity.  
Updated_ratings_data_df = ratings_data_df[['imdb_title_id', 'total_votes', 'weighted_average_vote', 'males_allages_avg_vote', 'males_allages_votes', 'females_allages_avg_vote', 'females_allages_votes']].copy()

# %%
Updated_ratings_data_df.set_index ("imdb_title_id", inplace = True)

# %%
Updated_ratings_data_df.head()
# Out:
#                total_votes  weighted_average_vote  males_allages_avg_vote  \
# imdb_title_id
# tt0000009              154                    5.9                     6.2
# tt0000574              589                    6.1                     6.1
# tt0001892              188                    5.8                     5.9
# tt0002101              446                    5.2                     5.1
# tt0002130             2237                    7.0                     7.0
#
#                males_allages_votes  females_allages_avg_vote  \
# imdb_title_id
# tt0000009                     97.0                       6.0
# tt0000574                    425.0                       6.2
# tt0001892                    146.0                       5.7
# tt0002101                    299.0                       5.9
# tt0002130                   1607.0                       7.2
#
#                females_allages_votes
# imdb_title_id
# tt0000009                       35.0
# ...

# %%
# Connect to database and create engine:
rds_connection_string = "postgres:bootcamp@localhost:5433/Netflix_IMDb_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Check tables
engine.table_names()
# Out:
# <ipython-input-9-d43c134ae484>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['ratings_gender']

# %%
# Verify that the databased is connected to the table. 
Updated_ratings_data_df.to_sql(name='ratings_gender', con=engine, if_exists='replace', index=True)
